# %%
import pandas as pd

# %%
df_software = pd.read_csv("CMDB_Software.csv")
df_windows_server = pd.read_csv("CMDB_Windows_Server.csv")

# %%
df_software.merge(df_windows_server, left_on="Related_CI_ID", right_on="CI_ID", how="inner"   )
# Out:
#     CI_ID_x Software_Name  Version Publisher Install_Date License  \
# 0   SW-7001        Chrome      1.0  Vendor-X   2024-01-01  Retail
# 1   SW-7003         Adobe      1.0  Vendor-X   2024-01-01  Retail
# 2   SW-7006         Adobe      1.0  Vendor-X   2024-01-01  Retail
# 3   SW-7007          Java      1.0  Vendor-X   2024-01-01  Retail
# 4   SW-7008         Adobe      1.0  Vendor-X   2024-01-01  Retail
# 5   SW-7010        Office      1.0  Vendor-X   2024-01-01  Retail
# 6   SW-7011        Chrome      1.0  Vendor-X   2024-01-01  Retail
# 7   SW-7012         Adobe      1.0  Vendor-X   2024-01-01  Retail
# 8   SW-7013          Java      1.0  Vendor-X   2024-01-01  Retail
# 9   SW-7014        Office      1.0  Vendor-X   2024-01-01  Retail
# 10  SW-7015        Office      1.0  Vendor-X   2024-01-01  Retail
# 11  SW-7016        Chrome      1.0  Vendor-X   2024-01-01  Retail
# 12  SW-7017        Office      1.0  Vendor-X   2024-01-01  Retail
# ...
